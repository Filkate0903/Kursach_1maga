# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from time import sleep
import json
from pymorphy2 import MorphAnalyzer
import re
from collections import OrderedDict
from dictdiffer import diff, patch, swap, revert

from selenium.webdriver import Firefox, FirefoxProfile, Proxy
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.common.proxy import ProxyType

from lxml import html

# %%
class SiteParser:
    def __init__(self):
        pass
    def get_morphems(self, word):
        pass
    def __del__(self):
        pass
    
class SiteParser1(SiteParser):
    def get_morphems(self, word):
        """Получает морфемы слова
        Обращается по адресу и выдает морфемы в виде списка [(морфема1, название1),(морфема2, название2), ...]
        """
        url = "https://kartaslov.ru/разбор-слова-по-составу/{}".format(word)
        text = requests.get(url).text
        soup = BeautifulSoup(text, 'html.parser')
        
        # у сайта проблемы, например, со словом пять, парсит другое слово(пятить), поэтому чекаем на совпадение с желаемым
        # сейчас просто ингорим, но может стоит выкидывать то что лишнее добавляется - надо исследовать
        word_on_site = re.match(".*«(.*)»", soup.find('h1', class_='v2-h1').text)
        if word_on_site.group(1) != word:
            return {"error":"site parsing error"}

        table = soup.find('table', class_='morphemics-table')
        if table is None:
            return {"error":"not found on site"}
        
        rows = table.findAll('tr')
        info = []
        for row in rows:
            info.append((row.find('td', class_='td-morpheme-text').text, row.find('td', class_='td-morpheme-type').text))
         
        return info  
    
class SiteParser2(SiteParser):
    def __init__(self):
        opts = Options()
        opts.set_headless()
        assert opts.headless
        #self.browser = Firefox(options=opts)
        
        my_proxy = Proxy({'proxyType': ProxyType.MANUAL,
        'httpProxy': '123.49.51.90:40881',
        'sslProxy': '123.49.51.90:40881',
        'noProxy': 'www.google-analytics.com, ajax.googleapis.com, apis.google.com'
        })

        self.browser = Firefox(proxy=my_proxy, options=opts, executable_path='C:\\Users\\NAD-ErmolaevPA\\Documents\\kitty_kursach\\geckodriver.exe')
        self.browser.get('https://udarenieru.ru/index.php?word=on')
        
    def get_morphems(self, word):
        """Получает морфемы слова
        Обращается по адресу и выдает морфемы в виде списка [(морфема1, название1),(морфема2, название2), ...]
        """
        self.browser.get('https://udarenieru.ru/index.php?word=on')
        self.browser.find_element_by_id('word_db').send_keys(word)
        self.browser.find_element_by_id('morph_book_D24').click()

        results = self.browser.find_elements_by_xpath('//*[@id="kuz_interpret"]/tbody/tr[1]/td/table')
        if results == []:
            return {"error":"not found on site"}
        res = results[0].text

        return [[x.strip() for x in y.split('—')] for y in res.split('\n')]
    
    def __del__(self):
        self.browser.close()
        
        
class SiteParser3(SiteParser):
    def get_morphems(self, word):
        """Получает морфемы слова
        Обращается по адресу и выдает морфемы в виде списка [(морфема1, название1),(морфема2, название2), ...]
        """
        url = "http://sostavslova.ru/{}/{}".format(word[0].upper(), word)
        text = requests.get(url).text
        
        soup = BeautifulSoup(text, 'html.parser')
        table = soup.find('p')
        if table is None:
            return {"error":"not found on site"}
        
        info = []
        mapper = {'w-pref':'приставка', 'w-root':'корень', 'w-suff':'суффикс', 'w-end':'окончание', 'w-end-null':'нулевое окончание', 'w-post':'постфикс'}
        for row in table.findAll('span'):
            cl = row.attrs['class'][0]
            text = row.text
            if cl.find('w-')!=-1:
                info.append((text, mapper[cl]))
                
        if info==[]:
            return {"error":"not found on site"}
        return info

# %%
url = "http://sostavslova.ru/{}/{}".format(word[0].upper(), word)
text = requests.get(url).text
soup = BeautifulSoup(text, 'html.parser')
table = soup.find('p')
info = []
mapper = {'w-pref':'приставка', 'w-root':'корень', 'w-suff':'суффикс', 'w-end':'окончание', 'w-end-null':'нулевое окончание'}
for row in table.findAll('span'):
    cl = row.attrs['class'][0]
    text = row.text
    if cl.find('w-')!=-1:
        info.append((mapper[cl], text))

# %%
info
# Out:
# [('приставка', 'при'),
#  ('корень', 'чес'),
#  ('суффикс', 'а'),
#  ('суффикс', 'ть'),
#  ('суффикс', 'ся')]

# %%
table.findAll('span')
# Out:
# [<span class="word"><span class="base"><span class="w-pref">при</span><span class="w-root">чес</span><span class="w-suff">а</span></span><span class="w-suff">ть</span><span class="base"><span class="w-suff">ся</span></span></span>,
#  <span class="base"><span class="w-pref">при</span><span class="w-root">чес</span><span class="w-suff">а</span></span>,
#  <span class="w-pref">при</span>,
#  <span class="w-root">чес</span>,
#  <span class="w-suff">а</span>,
#  <span class="w-suff">ть</span>,
#  <span class="base"><span class="w-suff">ся</span></span>,
#  <span class="w-suff">ся</span>]

# %%
class Analyzer:
    def __init__(self, site_parsers):
        self._analyzer = MorphAnalyzer()
        self._site_parsers = site_parsers

    def get_POS(self, word, analyzer='pymorphy'):
        """Получает часть речи для слова
        Для многозначных берем первое что показывает анализатор, возмножны проблемы
        Заложен вариант для остальных анализаторов, пока не реализован
        """
        if analyzer=='pymorphy':
            r = self._analyzer.parse(word)[0].tag.POS
            return r if r!='COMP' else 'ADJF'
        else:
            raise NotImplementedError
    
    def _get_dd(self, m):
        """Переводит список морфем и их названий в упорядоченный словарь
        """
        d = OrderedDict()
        for y in m:
            if len(y)==2:
                v, k = y
                v = v.replace('ё', 'е')
                if k in d:
                    d[k].append(v)
                else:
                    d[k] = [v]
        return d.copy()
    
    def _find(self, dif, action='add', morpheme='приставка'):
        """Ищет в dictdiffer различия определенного типа
        """
        for v in dif:
            if v[0]==action:
                if v[1]==morpheme: 
                    return True
                elif type(v[1])==list:
                    if v[1][0]==morpheme: 
                        return v[2]                  
                elif v[1]=='':
                    # thats in case [('add', '', [('приставка', ['при']), ('суффикс', ['ва'])])]
                    for i in v[2]:
                        if i[0]==morpheme:
                            return True
        return False

    def analyze(self, word1, word2, verbose=True):
        """Анализ слов на пердмет слообразования
        """
        #get morphemes
        
        for site_parser in self._site_parsers:
            m1 = site_parser.get_morphems(word1)
            if type(m1)!=dict:
                break
        
        for site_parser in self._site_parsers:
            m2 = site_parser.get_morphems(word2)
            if type(m2)!=dict:
                break
                
        
        #check if morphemes valid
        if 'error' in m1:
            if verbose: print('cant parse {}, error:'.format(word1, m1['error']))
            return 'UNKNOWN_PARSE_ERROR'       
        if 'error' in m2:
            if verbose: print('cant parse {}, error:'.format(word2, m2['error']))
            return 'UNKNOWN_PARSE_ERROR'    

        #revert morpheme list to ordered dict 
        m1 = self._get_dd(m1)
        m2 = self._get_dd(m2)
        
        #delete endings
        for v in ['глагольноеокончание', 'окончание', 'постфикс', 'нулевоеокончание', 'нулевое окончание', 'основа слова']:
            m1[v] = []
            m2[v] = []

        #get POS
        pos_pair = (self.get_POS(word1), self.get_POS(word2))
        
        #find dif
        dif = list(diff(m1, m2))
        if verbose: print(dif)
        
        #actual methods
        p = self._find(dif, action='add', morpheme='приставка') or self._find(dif, action='add', morpheme='префикс (приставка)') 
        s = self._find(dif, action='add', morpheme='суффикс') or self._find(dif, action='change', morpheme='суффикс') or self._find(dif, action='add', morpheme='интерфикс') or self._find(dif, action='change', morpheme='интерфикс')
        dk = self._find(dif, action='change', morpheme='корень')
        bs = self._find(dif, action='remove', morpheme='суффикс') or self._find(dif, action='remove', morpheme='интерфикс')
        
        ''' описание тегов из opencorpora
        NOUN	имя существительное	хомяк
        ADJF	имя прилагательное (полное)	хороший
        ADJS	имя прилагательное (краткое)	хорош
        COMP	компаратив	лучше, получше, выше ! WE COUNT IT AS ADJF !
        VERB	глагол (личная форма)	говорю, говорит, говорил
        INFN	глагол (инфинитив)	говорить, сказать
        PRTF	причастие (полное)	прочитавший, прочитанная
        PRTS	причастие (краткое)	прочитана
        GRND	деепричастие	прочитав, рассказывая
        NUMR	числительное	три, пятьдесят
        ADVB	наречие	круто
        NPRO	местоимение-существительное	он
        PRED	предикатив	некогда
        PREP	предлог	в
        CONJ	союз	и
        PRCL	частица	бы, же, лишь
        INTJ	междометие	ой
        
        '''
        # приставочный
        p_set = {('VERB', 'VERB'), ('VERB', 'INFN'), ('INFN', 'VERB'), ('INFN', 'INFN'),
                 ('NOUN', 'NOUN'), 
                 ('ADJF', 'ADJF'), ('ADJF', 'ADJS'), ('ADJS', 'ADJF'), ('ADJS', 'ADJS'),
                 ('NPRO', 'NPRO'),
                 ('ADVB', 'ADVB')}
        # суффиксальный
        s_set = {('NOUN', 'NOUN'), ('NOUN', 'ADJS'), ('NOUN', 'ADJF'), ('NOUN', 'VERB'), ('NOUN', 'INFN'),
                 ('VERB', 'VERB'), ('VERB', 'INFN'), ('VERB', 'NOUN'), ('VERB', 'ADJS'), ('VERB', 'ADJF'),
                 ('INFN', 'VERB'), ('INFN', 'INFN'), ('INFN', 'NOUN'), ('INFN', 'ADJS'), ('INFN', 'ADJF'),
                 ('ADJF', 'ADVB'), ('ADJF', 'NOUN'), ('ADJF', 'VERB'), ('ADJF', 'INFN'), ('ADJF', 'ADJF'),
                 ('ADJS', 'ADVB'), ('ADJS', 'NOUN'), ('ADJS', 'VERB'), ('ADJS', 'INFN'), ('ADJS', 'ADJS')}
        # приставочно-суффиксальный       
        ps_set = {('NOUN', 'NOUN'), 
                  ('NOUN', 'ADJF'), ('NOUN', 'ADJS'), 
                  ('NOUN', 'VERB'), ('NOUN', 'INFN'), ('ADJF', 'VERB'), ('ADJF', 'INFN'), ('ADJS', 'VERB'), ('ADJS', 'INFN'),
                  ('ADJF', 'ADVB'), ('ADJS', 'ADVB'), ('NOUN', 'ADVB'), ('NUMR', 'ADVB'),
                  ('INFN', 'INFN'), ('VERB', 'VERB'),# добавил я, надо чекать верно ли это
                  ('ADJF', 'CONJ'), ('ADJS', 'CONJ'),# добавил я, надо чекать верно ли это (пятый в-пятых)
                  ('ADVB', 'ADVB'),# добавил я, надо чекать верно ли это (век навеки
                 }
        # бессуфиксный    
        bs_set = {('INFN', 'NOUN'), ('VERB', 'NOUN'), 
                 ('ADJF', 'NOUN'), ('ADJS', 'NOUN'),
                 ('NOUN', 'NOUN'), 
                 ('NOUN', 'ADJF'), ('NOUN', 'ADJS'),
                 ('INFN', 'ADJF'), ('INFN', 'ADJS'), ('VERB', 'ADJF'), ('VERB', 'ADJS'),
                 ('ADJF', 'ADJF'), ('ADJF', 'ADJS'), ('ADJS', 'ADJF'), ('ADJS', 'ADJS'),
                 ('ADVB', 'ADJF'), ('ADVB', 'ADJS'),
                 ('NUMR', 'NUMR')}# проверить количественное-качественное
                 
        ## все далльше при условии что у нас только один корень!!!
        ## два надо отдельно смотреть
        if dk:
            #return "DIFF_ROOT"
            #теперь проверим вдруг жто чередующаяся согласыная
            if len(m1['корень'][0])==len(m2['корень'][0]):
                ss1 = {m1['корень'][0][-1], m2['корень'][0][-1]}
                ss2 = {m1['корень'][0][-1], m2['корень'][0][-2:]}
                ss3 = {m1['корень'][0][-2:], m2['корень'][0][-1]}
                ss4 = {m1['корень'][0][-2:], m2['корень'][0][-2:]}
                
                change_list = [{'г', 'ж'},{'г', 'жь'}, {'к', 'ч'}, {'д', 'ж'}, {'з', 'ж'}, {'к', 'ь'}, {'с', 'ш'},
                               {'т', 'ч'}, {'ч', 'т'}, {'ир', 'ор'}, {'ор', 'ар'}, {'ш', 'х'}, {'ит', 'ет'}]
                if (ss1 not in change_list) and (ss2 not in change_list) and (ss3 not in change_list) and (ss4 not in change_list):
                    return "DIFF_ROOT"   
        if (pos_pair in ps_set.union({pos_pair})) and p and s:
            if verbose: print(word1, '->', word2, ': приставочно-суффиксальный')
            return 'PS'
        if (pos_pair in p_set.union({pos_pair})) and  p:
            if verbose: print(word1, '->', word2, ': приставочный')
            return 'P'
        if (pos_pair in bs_set.union({pos_pair})) and (bs):
            if verbose: print(word1, '->', word2, ': безсуффиксный')
            return 'B'
        if (pos_pair in s_set.union({pos_pair})) and s:
            if verbose: print(word1, '->', word2, ': суффиксальный')
            return 'S'
        if (pos_pair in bs_set.union({pos_pair})) and (dk):
            if verbose: print(word1, '->', word2, ': безсуффиксный')
            return 'B'
        return 'UNKNOWN'

# %%
sp1 = SiteParser1()
sp3 = SiteParser3()

p = Analyzer([sp1, sp3])

# %%
TODO
посмотреть в обратном порядке - первое от второго или второе от первого
проверить части речи
# Out:
#   File "<ipython-input-363-de77897935a2>", line 2
#     посмотреть в обратном порядке - первое от второго или второе от первого
#                ^
# SyntaxError: invalid syntax

# %%
p.analyze('лес', 'лесной', verbose=True)
# Out:
# [('add', '', [('суффикс', ['н'])])]
# лес -> лесной : суффиксальный
# 'S'

# %%
test = pd.read_table('test.tsv', encoding='cp1251')

# %%
test.shape
# Out:
# (472, 4)

# %%
#test.drop_duplicates(keep='first', inplace=True)
#test.sort_values(by='label', inplace=True)
#test.reset_index(drop=True, inplace=True)
#test.to_csv('test.tsv', sep='\t')

# %%
res = []
for i, x in test.iterrows():
    print(i, x['word1'], x['word2'], end = ' ')
    res.append(p.analyze(x['word1'], x['word2'], True))
# Out:
# 0 надрезать надрез [('remove', '', [('суффикс', ['а', 'ть'])])]
# надрезать -> надрез : безсуффиксный
# 1 водить вождь [('change', ['корень', 0], ('вод', 'вождь')), ('remove', '', [('суффикс', ['и'])])]
# водить -> вождь : безсуффиксный
# 2 лед колоть ледокол cant parse лед колоть, error:
# 3 сталь варить сталевар cant parse сталь варить, error:
# 4 подорвать подрыв [('change', ['приставка', 0], ('подо', 'под')), ('change', ['корень', 0], ('рв', 'рыв')), ('remove', '', [('суффикс', ['а'])])]
# подорвать -> подрыв : безсуффиксный
# 5 отводить отвод [('remove', 'приставка', [(1, 'во')]), ('change', ['корень', 0], ('дить', 'вод'))]
# отводить -> отвод : безсуффиксный
# 6 дарить дар [('remove', '', [('суффикс', ['и'])])]
# дарить -> дар : безсуффиксный
# 7 взрывать взрыв [('remove', '', [('суффикс', ['а', 'ть'])])]
# взрывать -> взрыв : безсуффиксный
# 8 гладкий гладь [('change', ['корень', 0], ('гладк', 'гладь'))]
# гладкий -> гладь : безсуффиксный
# 9 глубокий глубь [('change', ['корень', 0], ('глубок', 'глубь'))]
# глубокий -> глубь : безсуффиксный
# 10 тихий тишь [('change', ['корень', 0], ('тих', 'тишь'))]
# тихий -> тишь : безсуффиксный
# 11 интеллигентный интеллигент [('remove', '', [('суффикс', ['н'])])]
# интеллигентный -> интеллигент : безсуффиксный
# 12 обслуживать обслуга [('change', ['корень', 0], ('служ', 'слуг')), ('remove', '', [('суффикс', ['ива'])])]
# обслуживать -> обслуга : безсуффиксный
# 13 кум кума []
# 14 лис лиса []
# 15 чёрный чернь [('change', ['корень', 0], ('черн', 'чернь'))]
# чёрный -> чернь : безсуффиксный
# 16 поросли поросль cant parse поросли, error:
# 17 золото золотой []
# 18 отец отчий [('change', ['корень', 0], ('отец', 'отч'))]
# отец -> отчий : безсуффиксный
# 19 орел орлий cant parse орел, error:
# 20 заехать заезжий [('change', ['корень', 0], ('ех', 'езж')), ('remove', '', [('суффикс', ['а'])])]
# заехать -> заезжий : безсуффиксный
# 21 ниже низший [('change', ['корень', 0], ('ниж', 'низ')), ('change', ['суффикс', 0], ('е', 'ш'))]
# ниже -> низший : суффиксальный
# 22 жалеть жаль [('change', ['корень', 0], ('жал', 'жаль')), ('remove', '', [('суффикс', ['е'])])]
# жалеть -> жаль : безсуффиксный
# 23 домыслить домысел [('change', ['корень', 0], ('мысл', 'мысел')), ('remove', '', [('суффикс', ['и'])])]
# домыслить -> домысел : безсуффиксный
# 24 доносить донос [('change', ['корень', 0], ('нос', 'донос')), ('remove', '', [('приставка', ['до']), ('суффикс', ['и', 'ть'])])]
# доносить -> донос : безсуффиксный
# 25 допускать допуск [('remove', '', [('суффикс', ['а'])])]
# допускать -> допуск : безсуффиксный
# 26 всходить всходы [('remove', '', [('суффикс', ['и'])])]
# всходить -> всходы : безсуффиксный
# 27 досмотреть досмотр [('remove', '', [('суффикс', ['е'])])]
# досмотреть -> досмотр : безсуффиксный
# 28 бежать бег [('change', ['корень', 0], ('беж', 'бег')), ('remove', '', [('суффикс', ['а'])])]
# бежать -> бег : безсуффиксный
# 29 подскочить подскок [('change', ['корень', 0], ('скоч', 'скок')), ('remove', '', [('суффикс', ['и'])])]
# подскочить -> подскок : безсуффиксный
# 30 вырезать вырез [('remove', '', [('суффикс', ['а'])])]
# вырезать -> вырез : безсуффиксный
# 31 выпускать выпуск [('remove', '', [('суффикс', ['а'])])]
# выпускать -> выпуск : безсуффиксный
# 32 выкрикнуть выкрик [('remove', '', [('суффикс', ['ну'])])]
# выкрикнуть -> выкрик : безсуффиксный
# 33 вызывать вызов [('change', ['корень', 0], ('зыв', 'зов')), ('remove', '', [('суффикс', ['а'])])]
# 34 выдохнуть выдох [('remove', '', [('суффикс', ['ну'])])]
# выдохнуть -> выдох : безсуффиксный
# 35 выговорить выговор [('remove', '', [('суффикс', ['и'])])]
# выговорить -> выговор : безсуффиксный
# 36 выводить вывод [('remove', '', [('суффикс', ['и', 'ть'])])]
# выводить -> вывод : безсуффиксный
# 37 вывихнуть вывих [('remove', '', [('суффикс', ['ну'])])]
# вывихнуть -> вывих : безсуффиксный
# 38 выбросить выброс [('remove', '', [('суффикс', ['и'])])]
# выбросить -> выброс : безсуффиксный
# 39 всхлипывать всхлип [('remove', '', [('суффикс', ['ыва'])])]
# всхлипывать -> всхлип : безсуффиксный
# 40 встречать встреча [('remove', '', [('суффикс', ['а'])])]
# встречать -> встреча : безсуффиксный
# 41 взмахнуть взмах [('remove', '', [('суффикс', ['ну'])])]
# взмахнуть -> взмах : безсуффиксный
# 42 взлететь взлёт [('remove', '', [('суффикс', ['е'])])]
# взлететь -> взлёт : безсуффиксный
# 43 взглянуть взгляд [('change', ['корень', 0], ('гля', 'гляд')), ('remove', '', [('суффикс', ['ну'])])]
# взглянуть -> взгляд : безсуффиксный
# 44 вводить ввод [('remove', '', [('суффикс', ['и'])])]
# вводить -> ввод : безсуффиксный
# 45 ввозить ввоз [('remove', '', [('суффикс', ['и'])])]
# ввозить -> ввоз : безсуффиксный
# 46 анализировать анализ [('remove', '', [('интерфикс', ['ир']), ('суффикс', ['ова'])])]
# анализировать -> анализ : безсуффиксный
# 47 подвод подводить [('add', '', [('суффикс', ['и'])])]
# подвод -> подводить : суффиксальный
# 48 разъезд разъезжать [('change', ['корень', 0], ('езд', 'езж')), ('add', '', [('суффикс', ['а'])])]
# разъезд -> разъезжать : суффиксальный
# 49 залив заливать cant parse заливать, error:
# 50 считать счет cant parse считать, error:
# 51 допросить допрос [('remove', '', [('суффикс', ['и'])])]
# допросить -> допрос : безсуффиксный
# 52 шагать шаг [('remove', '', [('суффикс', ['а'])])]
# шагать -> шаг : безсуффиксный
# 53 привалить привал [('remove', '', [('суффикс', ['и'])])]
# привалить -> привал : безсуффиксный
# 54 заплывать заплыв [('change', ['суффикс', 0], ('ва', 'в')), ('remove', 'суффикс', [(1, 'ть')])]
# заплывать -> заплыв : безсуффиксный
# 55 ходить ход [('remove', '', [('суффикс', ['и'])])]
# ходить -> ход : безсуффиксный
# 56 высевать высев [('change', ['суффикс', 0], ('ва', 'в'))]
# высевать -> высев : суффиксальный
# 57 загибать загиб [('remove', '', [('суффикс', ['а'])])]
# загибать -> загиб : безсуффиксный
# 58 заезжать заезд [('change', ['корень', 0], ('езж', 'езд')), ('remove', '', [('суффикс', ['а'])])]
# заезжать -> заезд : безсуффиксный
# 59 упрекать упрёк [('remove', '', [('суффикс', ['а'])])]
# упрекать -> упрёк : безсуффиксный
# 60 высокий высь [('change', ['корень', 0], ('высок', 'высь'))]
# высокий -> высь : безсуффиксный
# 61 задирать задира [('remove', '', [('суффикс', ['а'])])]
# задирать -> задира : безсуффиксный
# 62 восходить восход [('remove', '', [('суффикс', ['и'])])]
# восходить -> восход : безсуффиксный
# 63 зеленый зелень cant parse зеленый, error:
# 64 удалой удаль [('change', ['корень', 0], ('удал', 'удаль'))]
# удалой -> удаль : безсуффиксный
# 65 входить вход [('remove', '', [('суффикс', ['и'])])]
# входить -> вход : безсуффиксный
# 66 вылететь вылет [('remove', '', [('суффикс', ['е'])])]
# вылететь -> вылет : безсуффиксный
# 67 щебетать щебет [('remove', '', [('суффикс', ['а'])])]
# щебетать -> щебет : безсуффиксный
# 68 расплатиться расплата [('remove', '', [('суффикс', ['и'])])]
# расплатиться -> расплата : безсуффиксный
# 69 заслужить заслуга [('change', ['корень', 0], ('служ', 'слуг')), ('remove', '', [('суффикс', ['и'])])]
# заслужить -> заслуга : безсуффиксный
# 70 бранить брань [('change', ['корень', 0], ('бран', 'брань')), ('remove', '', [('суффикс', ['и'])])]
# бранить -> брань : безсуффиксный
# 71 дрожать дрожь [('change', ['корень', 0], ('дрож', 'дрожь')), ('remove', '', [('суффикс', ['а'])])]
# дрожать -> дрожь : безсуффиксный
# 72 реветь рева cant parse рева, error:
# 73 примитивный примитив [('remove', '', [('суффикс', ['н'])])]
# примитивный -> примитив : безсуффиксный
# 74 оригинальный оригинал [('change', ['корень', 0], ('оригинальн', 'оригинал'))]
# оригинальный -> оригинал : безсуффиксный
# 75 густой гуща [('change', ['корень', 0], ('густ', 'гущ'))]
# густой -> гуща : безсуффиксный
# 76 крутой круча [('change', ['корень', 0], ('крут', 'круч'))]
# крутой -> круча : безсуффиксный
# 77 синий синь [('change', ['корень', 0], ('син', 'синь'))]
# синий -> синь : безсуффиксный
# 78 глухой глушь [('change', ['корень', 0], ('глух', 'глушь'))]
# глухой -> глушь : безсуффиксный
# 79 рассказать рассказ [('remove', '', [('суффикс', ['а'])])]
# рассказать -> рассказ : безсуффиксный
# 80 сухой сушь [('change', ['корень', 0], ('сух', 'сушь'))]
# сухой -> сушь : безсуффиксный
# 81 далекий даль cant parse далекий, error:
# 82 спорить спор [('remove', '', [('суффикс', ['и'])])]
# спорить -> спор : безсуффиксный
# 83 переходить переход [('remove', '', [('суффикс', ['и'])])]
# переходить -> переход : безсуффиксный
# 84 уплатить уплата [('remove', '', [('суффикс', ['и'])])]
# уплатить -> уплата : безсуффиксный
# 85 загонять загон [('remove', '', [('суффикс', ['я'])])]
# загонять -> загон : безсуффиксный
# 86 уличить улика [('change', ['корень', 0], ('улич', 'улик')), ('remove', '', [('суффикс', ['и'])])]
# уличить -> улика : безсуффиксный
# 87 примешать примесь [('change', ['корень', 0], ('меш', 'месь')), ('remove', '', [('суффикс', ['а'])])]
# примешать -> примесь : безсуффиксный
# 88 зажимать зажим [('remove', '', [('суффикс', ['а'])])]
# зажимать -> зажим : безсуффиксный
# 89 заказать заказ [('remove', '', [('суффикс', ['а', 'ть'])])]
# заказать -> заказ : безсуффиксный
# 90 закатиться заказ [('change', ['корень', 0], ('кат', 'заказ')), ('remove', '', [('приставка', ['за']), ('суффикс', ['и'])])]
# закатиться -> заказ : безсуффиксный
# 91 залежаться залежь [('change', ['корень', 0], ('леж', 'лежь')), ('remove', '', [('суффикс', ['а'])])]
# залежаться -> залежь : безсуффиксный
# 92 заливать залив cant parse заливать, error:
# 93 заложить залог cant parse залог, error:
# 94 нажимать нажим [('remove', '', [('суффикс', ['а'])])]
# нажимать -> нажим : безсуффиксный
# 95 накатить накат [('remove', '', [('суффикс', ['и'])])]
# накатить -> накат : безсуффиксный
# 96 накипать накипь [('change', ['корень', 0], ('кип', 'кипь')), ('remove', '', [('суффикс', ['а'])])]
# накипать -> накипь : безсуффиксный
# 97 наклонять наклон [('remove', '', [('суффикс', ['я'])])]
# наклонять -> наклон : безсуффиксный
# 98 перехватить перехват [('remove', '', [('суффикс', ['и'])])]
# перехватить -> перехват : безсуффиксный
# 99 победить победа [('remove', '', [('суффикс', ['и'])])]
# победить -> победа : безсуффиксный
# 100 повторить повтор [('remove', '', [('суффикс', ['и'])])]
# повторить -> повтор : безсуффиксный
# 101 погоняться погоня [('remove', '', [('суффикс', ['я', 'ть', 'ся'])])]
# погоняться -> погоня : безсуффиксный
# 102 покосить покос [('remove', '', [('суффикс', ['и', 'ть'])])]
# покосить -> покос : безсуффиксный
# 103 покрывать покров cant parse покров, error:
# 104 почитать почёт [('change', ['корень', 0], ('чит', 'чет')), ('remove', '', [('суффикс', ['а'])])]
# почитать -> почёт : безсуффиксный
# 105 пощадить пощада [('remove', '', [('суффикс', ['и'])])]
# пощадить -> пощада : безсуффиксный
# 106 преградить преграда [('remove', '', [('суффикс', ['и'])])]
# преградить -> преграда : безсуффиксный
# 107 приветствовать привет [('remove', '', [('суффикс', ['ств', 'ова'])])]
# приветствовать -> привет : безсуффиксный
# 108 приговорить приговор [('remove', '', [('суффикс', ['и'])])]
# приговорить -> приговор : безсуффиксный
# 109 приезжать приезд [('change', ['корень', 0], ('езж', 'езд')), ('remove', '', [('суффикс', ['а'])])]
# приезжать -> приезд : безсуффиксный
# 110 принимать приём [('change', ['корень', 0], ('приним', 'прием')), ('remove', '', [('суффикс', ['а'])])]
# принимать -> приём : безсуффиксный
# 111 приказать приказ [('remove', '', [('суффикс', ['а'])])]
# приказать -> приказ : безсуффиксный
# 112 прикладывать приклад [('remove', '', [('суффикс', ['ыва'])])]
# прикладывать -> приклад : безсуффиксный
# 113 укусить укус [('remove', '', [('суффикс', ['и'])])]
# укусить -> укус : безсуффиксный
# 114 выстрелить выстрел [('remove', '', [('суффикс', ['и'])])]
# выстрелить -> выстрел : безсуффиксный
# 115 вздохнуть вздох [('remove', '', [('суффикс', ['ну'])])]
# вздохнуть -> вздох : безсуффиксный
# 116 выступать выступ [('remove', '', [('суффикс', ['а'])])]
# выступать -> выступ : безсуффиксный
# 117 сгибать сгиб [('remove', '', [('суффикс', ['а'])])]
# сгибать -> сгиб : безсуффиксный
# 118 свистеть свист [('remove', '', [('суффикс', ['е'])])]
# свистеть -> свист : безсуффиксный
# 119 разбирать разбор [('change', ['корень', 0], ('бир', 'бор')), ('remove', '', [('суффикс', ['а'])])]
# разбирать -> разбор : безсуффиксный
# 120 разбегаться разбег [('remove', '', [('суффикс', ['а'])])]
# разбегаться -> разбег : безсуффиксный
# 121 прясть пряжа [('change', ['корень', 0], ('пряс', 'пря')), ('add', '', [('суффикс', ['ж'])])]
# прясть -> пряжа : суффиксальный
# 122 примечать примета [('change', ['корень', 0], ('меч', 'мет')), ('remove', '', [('суффикс', ['а'])])]
# примечать -> примета : безсуффиксный
# 123 пересматривать пересмотр [('change', ['корень', 0], ('сматр', 'смотр')), ('remove', '', [('суффикс', ['ива'])])]
# 124 пересказывать пересказ [('remove', '', [('суффикс', ['ыва'])])]
# пересказывать -> пересказ : безсуффиксный
# 125 перерасходовать перерасход [('remove', '', [('суффикс', ['ова'])])]
# перерасходовать -> перерасход : безсуффиксный
# 126 прибиваться прибой [('change', ['корень', 0], ('би', 'бой')), ('remove', '', [('суффикс', ['ва'])])]
# прибиваться -> прибой : безсуффиксный
# 127 переправиться переправа [('remove', '', [('суффикс', ['и'])])]
# переправиться -> переправа : безсуффиксный
# 128 переломать перелом [('remove', '', [('суффикс', ['а'])])]
# переломать -> перелом : безсуффиксный
# 129 переносить перенос [('remove', '', [('суффикс', ['и', 'ть'])])]
# переносить -> перенос : безсуффиксный
# 130 переменить перемена [('remove', '', [('суффикс', ['и'])])]
# переменить -> перемена : безсуффиксный
# 131 переломить перелом [('remove', '', [('суффикс', ['и'])])]
# переломить -> перелом : безсуффиксный
# 132 перебрать перебор [('change', ['корень', 0], ('бр', 'бор')), ('remove', '', [('суффикс', ['а'])])]
# перебрать -> перебор : безсуффиксный
# 133 охранять охрана [('remove', '', [('суффикс', ['я'])])]
# охранять -> охрана : безсуффиксный
# 134 отвечать ответ [('change', ['корень', 0], ('отвеч', 'ответ')), ('remove', '', [('суффикс', ['а'])])]
# отвечать -> ответ : безсуффиксный
# 135 выхлопать выхлоп [('remove', '', [('суффикс', ['а'])])]
# выхлопать -> выхлоп : безсуффиксный
# 136 осадить осада [('change', ['корень', 0], ('сад', 'осад')), ('remove', '', [('приставка', ['о']), ('суффикс', ['и'])])]
# осадить -> осада : безсуффиксный
# 137 ориентироваться ориентир [('remove', 'суффикс', [(1, 'ова')])]
# ориентироваться -> ориентир : безсуффиксный
# 138 опрашивать опрос [('change', ['корень', 0], ('праш', 'прос')), ('remove', '', [('суффикс', ['ива'])])]
# опрашивать -> опрос : безсуффиксный
# 139 оправить оправа [('change', ['корень', 0], ('прав', 'оправ')), ('remove', '', [('приставка', ['о']), ('суффикс', ['и'])])]
# оправить -> оправа : безсуффиксный
# 140 опираться опора [('change', ['корень', 0], ('пир', 'пор')), ('remove', '', [('суффикс', ['а'])])]
# опираться -> опора : безсуффиксный
# 141 описать опись [('change', ['корень', 0], ('пис', 'пись')), ('remove', '', [('суффикс', ['а'])])]
# описать -> опись : безсуффиксный
# 142 обстрелять обстрел [('remove', '', [('суффикс', ['я'])])]
# обстрелять -> обстрел : безсуффиксный
# 143 обряжать обряд [('change', ['корень', 0], ('ряж', 'обряд')), ('remove', '', [('приставка', ['об']), ('суффикс', ['а'])])]
# обряжать -> обряд : безсуффиксный
# 144 сговориться сговор [('remove', '', [('суффикс', ['и'])])]
# сговориться -> сговор : безсуффиксный
# 145 сдвигать сдвиг [('remove', '', [('суффикс', ['а'])])]
# сдвигать -> сдвиг : безсуффиксный
# 146 скосить скос [('remove', '', [('суффикс', ['и'])])]
# скосить -> скос : безсуффиксный
# 147 скрежетать скрежет [('remove', '', [('суффикс', ['а'])])]
# скрежетать -> скрежет : безсуффиксный
# 148 шелестеть шелест [('remove', '', [('суффикс', ['е'])])]
# шелестеть -> шелест : безсуффиксный
# 149 хрустеть хруст [('remove', '', [('суффикс', ['е'])])]
# хрустеть -> хруст : безсуффиксный
# 150 хохотать хохот [('remove', 'суффикс', [(1, 'а')])]
# хохотать -> хохот : безсуффиксный
# 151 хвалить хвала [('remove', '', [('суффикс', ['и'])])]
# хвалить -> хвала : безсуффиксный
# 152 трещать треск [('change', ['корень', 0], ('трещ', 'треск')), ('remove', '', [('суффикс', ['а'])])]
# трещать -> треск : безсуффиксный
# 153 трепетать трепет [('remove', '', [('суффикс', ['а'])])]
# трепетать -> трепет : безсуффиксный
# 154 тормозить тормоз [('remove', '', [('суффикс', ['и'])])]
# тормозить -> тормоз : безсуффиксный
# 155 травить травля [('change', ['корень', 0], ('трав', 'травл')), ('remove', '', [('суффикс', ['и'])])]
# травить -> травля : безсуффиксный
# 156 уходить уход [('remove', '', [('суффикс', ['и', 'ть'])])]
# уходить -> уход : безсуффиксный
# 157 утратить утрата [('remove', '', [('суффикс', ['и'])])]
# утратить -> утрата : безсуффиксный
# 158 услужить услуга [('change', ['корень', 0], ('служ', 'слуг')), ('remove', '', [('суффикс', ['и'])])]
# услужить -> услуга : безсуффиксный
# 159 уронить урон [('remove', '', [('суффикс', ['и'])])]
# уронить -> урон : безсуффиксный
# 160 уколоть укол [('remove', '', [('суффикс', ['о'])])]
# уколоть -> укол : безсуффиксный
# 161 обрывать обрыв [('change', ['суффикс', 0], ('ва', 'в')), ('remove', 'суффикс', [(1, 'ть')])]
# обрывать -> обрыв : безсуффиксный
# 162 укладывать уклад [('remove', '', [('суффикс', ['ыва'])])]
# укладывать -> уклад : безсуффиксный
# 163 ударить удар [('remove', '', [('суффикс', ['и', 'ть'])])]
# ударить -> удар : безсуффиксный
# 164 уговориться уговор [('remove', '', [('суффикс', ['и'])])]
# уговориться -> уговор : безсуффиксный
# 165 угореть угар [('change', ['корень', 0], ('гор', 'гар')), ('remove', '', [('суффикс', ['е'])])]
# угореть -> угар : безсуффиксный
# 166 убирать убор [('change', ['корень', 0], ('бир', 'бор')), ('remove', '', [('суффикс', ['а'])])]
# убирать -> убор : безсуффиксный
# 167 снарядить снаряд [('change', ['корень', 0], ('наряд', 'снаряд')), ('remove', '', [('приставка', ['с']), ('суффикс', ['и'])])]
# снарядить -> снаряд : безсуффиксный
# 168 смыслить смысл [('remove', '', [('суффикс', ['и'])])]
# смыслить -> смысл : безсуффиксный
# 169 смотреть смотр [('remove', '', [('суффикс', ['е'])])]
# смотреть -> смотр : безсуффиксный
# 170 смешать смесь [('change', ['корень', 0], ('меш', 'месь')), ('remove', '', [('суффикс', ['а'])])]
# смешать -> смесь : безсуффиксный
# 171 сменить смена [('remove', '', [('суффикс', ['и'])])]
# сменить -> смена : безсуффиксный
# 172 сломать слом [('remove', '', [('суффикс', ['а'])])]
# сломать -> слом : безсуффиксный
# 173 слетаться слёт [('change', ['корень', 0], ('сле', 'лет')), ('add', '', [('приставка', ['с'])]), ('remove', '', [('суффикс', ['т', 'а'])])]
# 174 скучать скука [('change', ['корень', 0], ('скуч', 'скук')), ('remove', '', [('суффикс', ['а'])])]
# скучать -> скука : безсуффиксный
# 175 скрипеть скрип [('remove', '', [('суффикс', ['е'])])]
# скрипеть -> скрип : безсуффиксный
# 176 уделить удел [('change', ['корень', 0], ('дел', 'удел')), ('remove', '', [('приставка', ['у']), ('суффикс', ['и'])])]
# уделить -> удел : безсуффиксный
# 177 обрезать обрез [('remove', '', [('суффикс', ['а'])])]
# обрезать -> обрез : безсуффиксный
# 178 оскалиться оскал [('remove', '', [('суффикс', ['и'])])]
# оскалиться -> оскал : безсуффиксный
# 179 наряжать наряд cant parse наряжать, error:
# 180 выходить выход [('remove', '', [('суффикс', ['и'])])]
# выходить -> выход : безсуффиксный
# 181 доводить довод [('change', ['корень', 0], ('вод', 'довод')), ('remove', '', [('приставка', ['до']), ('суффикс', ['и'])])]
# доводить -> довод : безсуффиксный
# 182 договориться договор [('remove', '', [('суффикс', ['и'])])]
# договориться -> договор : безсуффиксный
# 183 докладывать доклад cant parse докладывать, error:
# 184 ездить зда cant parse зда, error:
# 185 износить износ [('remove', '', [('суффикс', ['и'])])]
# износить -> износ : безсуффиксный
# 186 изменить измена cant parse изменить, error:
# 187 забегать забег [('remove', '', [('суффикс', ['а'])])]
# забегать -> забег : безсуффиксный
# 188 забивать забой [('change', ['корень', 0], ('заб', 'бой')), ('add', '', [('приставка', ['за'])]), ('remove', '', [('суффикс', ['ива'])])]
# 189 забирать забор [('change', ['корень', 0], ('бир', 'забор')), ('remove', '', [('приставка', ['за']), ('суффикс', ['а', 'ть'])])]
# забирать -> забор : безсуффиксный
# 190 заботиться забота [('remove', '', [('суффикс', ['и'])])]
# заботиться -> забота : безсуффиксный
# 191 оборонять оборона [('remove', '', [('суффикс', ['я'])])]
# оборонять -> оборона : безсуффиксный
# 192 завалить завал [('remove', '', [('суффикс', ['и'])])]
# завалить -> завал : безсуффиксный
# 193 завесить завеса [('remove', '', [('суффикс', ['и'])])]
# завесить -> завеса : безсуффиксный
# 194 завидовать зависть [('change', ['корень', 0], ('завид', 'зависть')), ('remove', '', [('суффикс', ['ова'])])]
# завидовать -> зависть : безсуффиксный
# 195 заводить завод cant parse завод, error:
# 196 завозить завоз [('change', ['корень', 0], ('зав', 'воз')), ('add', '', [('приставка', ['за'])]), ('remove', '', [('суффикс', ['оз', 'и'])])]
# 197 загорать загар [('change', ['корень', 0], ('гор', 'гар')), ('remove', '', [('суффикс', ['а'])])]
# загорать -> загар : безсуффиксный
# 198 замахнуться замах [('remove', '', [('суффикс', ['ну'])])]
# замахнуться -> замах : безсуффиксный
# 199 замесить замес [('remove', '', [('суффикс', ['и'])])]
# замесить -> замес : безсуффиксный
# 200 изломать излом [('remove', '', [('суффикс', ['а'])])]
# изломать -> излом : безсуффиксный
# 201 изгибать изгиб [('remove', '', [('суффикс', ['а'])])]
# изгибать -> изгиб : безсуффиксный
# 202 засушить засуха [('change', ['корень', 0], ('суш', 'сух')), ('remove', '', [('суффикс', ['и'])])]
# засушить -> засуха : безсуффиксный
# 203 вычитать вычет [('change', ['корень', 0], ('чит', 'чет')), ('remove', '', [('суффикс', ['а', 'ть'])])]
# вычитать -> вычет : безсуффиксный
# 204 звенит звон cant parse звенит, error:
# 205 извиваться извив [('change', ['суффикс', 0], ('ва', 'в'))]
# извиваться -> извив : суффиксальный
# 206 набирать набор [('change', ['корень', 0], ('бир', 'бор')), ('remove', '', [('суффикс', ['а'])])]
# набирать -> набор : безсуффиксный
# 207 наливать налив [('change', ['суффикс', 0], ('ва', 'в'))]
# наливать -> налив : суффиксальный
# 208 налететь налёт [('remove', '', [('суффикс', ['е'])])]
# налететь -> налёт : безсуффиксный
# 209 надрывать надрыв [('remove', '', [('суффикс', ['а'])])]
# надрывать -> надрыв : безсуффиксный
# 210 надзирать надзор [('change', ['корень', 0], ('надзир', 'надзор')), ('remove', '', [('суффикс', ['а'])])]
# надзирать -> надзор : безсуффиксный
# 211 наплывать наплыв [('change', ['суффикс', 0], ('ва', 'в'))]
# наплывать -> наплыв : суффиксальный
# 212 наделять надел [('remove', '', [('суффикс', ['я'])])]
# наделять -> надел : безсуффиксный
# 213 нагревать нагрев [('change', ['суффикс', 0], ('ва', 'в'))]
# нагревать -> нагрев : суффиксальный
# 214 навесить навес [('remove', '', [('суффикс', ['и'])])]
# навесить -> навес : безсуффиксный
# 215 нарастать нарост [('change', ['корень', 0], ('раст', 'рост')), ('remove', '', [('суффикс', ['а'])])]
# 216 махнуть мах [('remove', '', [('суффикс', ['ну'])])]
# махнуть -> мах : безсуффиксный
# 217 ломать лом [('remove', '', [('суффикс', ['а'])])]
# ломать -> лом : безсуффиксный
# 218 ловить ловля [('change', ['корень', 0], ('лов', 'ловл')), ('remove', '', [('суффикс', ['и', 'ть'])])]
# ловить -> ловля : безсуффиксный
# 219 конспектировать конспект [('remove', '', [('интерфикс', ['ир']), ('суффикс', ['ова'])])]
# конспектировать -> конспект : безсуффиксный
# 220 клеймить клеймо [('remove', '', [('суффикс', ['и'])])]
# клеймить -> клеймо : безсуффиксный
# 221 клеить клей [('change', ['корень', 0], ('кле', 'клей')), ('remove', '', [('суффикс', ['и'])])]
# клеить -> клей : безсуффиксный
# 222 клеветать клевета [('remove', '', [('суффикс', ['а'])])]
# клеветать -> клевета : безсуффиксный
# 223 клевать клёв [('change', ['корень', 0], ('клева', 'клев'))]
# клевать -> клёв : безсуффиксный
# 224 исходить исход [('change', ['корень', 0], ('ход', 'исход')), ('remove', '', [('приставка', ['ис']), ('суффикс', ['и', 'ть'])])]
# исходить -> исход : безсуффиксный
# 225 испугать испуг [('remove', '', [('суффикс', ['а'])])]
# испугать -> испуг : безсуффиксный
# 226 исповедоваться исповедь [('change', ['корень', 0], ('исповед', 'исповедь')), ('remove', '', [('суффикс', ['ова'])])]
# исповедоваться -> исповедь : безсуффиксный
# 227 импортировать импорт [('remove', '', [('интерфикс', ['ир']), ('суффикс', ['ова'])])]
# импортировать -> импорт : безсуффиксный
# 228 намекать намёк [('remove', '', [('суффикс', ['а', 'ть'])])]
# намекать -> намёк : безсуффиксный
# 229 нанести нанос [('change', ['корень', 0], ('нес', 'нос'))]
# 230 кто кое-кто [('change', ['корень', 0], ('кто', 'кое')), ('add', 'корень', [(1, 'кто')])]
# 231 читать прочитать [('add', '', [('приставка', ['про'])])]
# читать -> прочитать : приставочный
# 232 добрый предобрый [('add', '', [('приставка', ['пре'])])]
# добрый -> предобрый : приставочный
# 233 весело невесело cant parse весело, error:
# 234 плыть отплыть [('add', '', [('приставка', ['от'])])]
# плыть -> отплыть : приставочный
# 235 порядок беспорядок [('add', '', [('приставка', ['бес'])])]
# порядок -> беспорядок : приставочный
# 236 жечь отжечь [('add', '', [('приставка', ['от'])])]
# жечь -> отжечь : приставочный
# 237 ходить восходить [('add', '', [('приставка', ['вос'])])]
# ходить -> восходить : приставочный
# 238 страдать сострадать [('change', ['корень', 0], ('страда', 'страд')), ('add', '', [('приставка', ['со']), ('суффикс', ['а'])])]
# страдать -> сострадать : приставочно-суффиксальный
# 239 носить возносить [('add', '', [('приставка', ['воз'])])]
# носить -> возносить : приставочный
# 240 модный сверхмодный [('add', '', [('приставка', ['сверх'])])]
# модный -> сверхмодный : приставочный
# 241 лево налево [('add', '', [('приставка', ['на']), ('суффикс', ['о'])])]
# лево -> налево : приставочно-суффиксальный
# 242 когда никогда [('add', '', [('приставка', ['ни'])])]
# когда -> никогда : приставочный
# 243 кто никто [('add', '', [('приставка', ['ни'])])]
# кто -> никто : приставочный
# 244 бежать сбежать [('add', '', [('приставка', ['с'])])]
# бежать -> сбежать : приставочный
# 245 решать разрешать [('change', ['корень', 0], ('реш', 'разреш'))]
# решать -> разрешать : безсуффиксный
# 246 делать сделать [('add', '', [('приставка', ['с'])])]
# делать -> сделать : приставочный
# 247 плескать выплескать [('add', '', [('приставка', ['вы'])])]
# плескать -> выплескать : приставочный
# 248 грызть загрызть [('add', '', [('приставка', ['за'])])]
# грызть -> загрызть : приставочный
# 249 бежать прибежать [('add', '', [('приставка', ['при'])])]
# бежать -> прибежать : приставочный
# 250 бить прибить [('add', '', [('приставка', ['при'])])]
# бить -> прибить : приставочный
# 251 сердиться рассердиться [('add', '', [('приставка', ['рас'])])]
# сердиться -> рассердиться : приставочный
# 252 знать познать cant parse знать, error:
# 253 стоять отстоять [('add', '', [('приставка', ['от'])])]
# стоять -> отстоять : приставочный
# 254 мобилизация демобилизация [('change', ['суффикс', 0], ('из', 'аци')), ('remove', 'суффикс', [(1, 'аци')]), ('add', '', [('приставка', ['де']), ('интерфикс', ['из'])])]
# мобилизация -> демобилизация : приставочно-суффиксальный
# 255 революция контрреволюция [('add', '', [('приставка', ['контр'])])]
# революция -> контрреволюция : приставочный
# 256 автор соавтор [('add', '', [('приставка', ['со'])])]
# автор -> соавтор : приставочный
# 257 вкус привкус [('add', '', [('приставка', ['при'])])]
# вкус -> привкус : приставочный
# 258 заголовок подзаголовок [('change', ['приставка', 0], ('за', 'под')), ('add', 'приставка', [(1, 'за')])]
# заголовок -> подзаголовок : приставочный
# 259 пол подпол [('add', '', [('приставка', ['под'])])]
# пол -> подпол : приставочный
# 260 бабушка прабабушка [('add', '', [('приставка', ['пра'])])]
# бабушка -> прабабушка : приставочный
# 261 вооружить перевооружить [('change', ['приставка', 0], ('во', 'пере')), ('add', 'приставка', [(1, 'во')])]
# вооружить -> перевооружить : приставочный
# 262 кто некто [('add', '', [('приставка', ['не'])])]
# кто -> некто : приставочный
# 263 полярный приполярный [('add', '', [('приставка', ['при'])])]
# полярный -> приполярный : приставочный
# 264 злой презлой [('add', '', [('приставка', ['пре'])])]
# злой -> презлой : приставочный
# 265 странный престранный [('add', '', [('приставка', ['пре'])])]
# странный -> престранный : приставочный
# 266 вне вовне [('add', '', [('приставка', ['во'])])]
# вне -> вовне : приставочный
# 267 атлантический трансатлантический [('add', '', [('приставка', ['транс'])])]
# атлантический -> трансатлантический : приставочный
# 268 тропический субтропический cant parse тропический, error:
# 269 моральный аморальный [('add', '', [('приставка', ['а'])])]
# моральный -> аморальный : приставочный
# 270 общественный антиобщественный [('change', ['суффикс', 0], ('е', 'еств')), ('change', ['суффикс', 1], ('ств', 'енн')), ('remove', 'суффикс', [(2, 'енн')]), ('add', '', [('приставка', ['анти'])])]
# общественный -> антиобщественный : приставочно-суффиксальный
# 271 нельзя донельзя [('add', '', [('приставка', ['до'])])]
# нельзя -> донельзя : приставочный
# 272 какой никакой [('add', '', [('приставка', ['ни'])])]
# какой -> никакой : приставочный
# 273 сколько несколько [('add', '', [('приставка', ['не'])])]
# сколько -> несколько : приставочный
# 274 что кое-что [('change', ['корень', 0], ('что', 'кое')), ('add', 'корень', [(1, 'что')])]
# 275 когда некогда [('add', '', [('приставка', ['не'])])]
# когда -> некогда : приставочный
# 276 петь перепеть [('add', '', [('приставка', ['пере'])])]
# петь -> перепеть : приставочный
# 277 петь допеть [('add', '', [('приставка', ['до'])])]
# петь -> допеть : приставочный
# 278 петь запеть [('add', '', [('приставка', ['за']), ('суффикс', ['ть'])])]
# петь -> запеть : приставочно-суффиксальный
# 279 ныне поныне [('change', ['корень', 0], ('ныне', 'нын')), ('add', '', [('приставка', ['по']), ('суффикс', ['е'])])]
# ныне -> поныне : приставочно-суффиксальный
# 280 одаренный сверходаренный cant parse одаренный, error:
# 281 ходит  выходить cant parse ходит , error:
# 282 комфорт дискомфорт [('add', '', [('приставка', ['дис'])])]
# комфорт -> дискомфорт : приставочный
# 283 плыть переплыть [('add', '', [('приставка', ['пере'])])]
# плыть -> переплыть : приставочный
# 284 удалый разудалый [('add', '', [('приставка', ['раз'])])]
# удалый -> разудалый : приставочный
# 285 громкий сверхгромкий cant parse сверхгромкий, error:
# 286 континент субконтинент [('add', '', [('приставка', ['суб'])])]
# континент -> субконтинент : приставочный
# 287 ориентация дезориентация [('add', '', [('приставка', ['дез'])])]
# ориентация -> дезориентация : приставочный
# 288 прочь напрочь [('add', '', [('приставка', ['на'])])]
# прочь -> напрочь : приставочный
# 289 ныне отныне [('add', '', [('приставка', ['от'])])]
# ныне -> отныне : приставочный
# 290 пополам напополам [('change', ['приставка', 0], ('по', 'на')), ('add', 'приставка', [(1, 'по')])]
# пополам -> напополам : приставочный
# 291 всегда навсегда [('add', '', [('приставка', ['на'])])]
# всегда -> навсегда : приставочный
# 292 даром задаром [('add', '', [('приставка', ['за'])])]
# даром -> задаром : приставочный
# 293 учить выучить [('add', '', [('приставка', ['вы'])])]
# учить -> выучить : приставочный
# 294 бежать убежать [('add', '', [('приставка', ['у'])])]
# бежать -> убежать : приставочный
# 295 ходить выходить [('add', '', [('приставка', ['вы'])])]
# ходить -> выходить : приставочный
# 296 лечение излечение [('add', '', [('приставка', ['из'])])]
# лечение -> излечение : приставочный
# 297 стройка перестройка [('add', '', [('приставка', ['пере'])])]
# стройка -> перестройка : приставочный
# 298 как никак cant parse как, error:
# 299 седлать оседлать [('add', '', [('приставка', ['о'])])]
# седлать -> оседлать : приставочный
# 300 кликнуть воскликнуть [('change', ['корень', 0], ('клик', 'воск')), ('change', ['суффикс', 0], ('ну', 'лик')), ('add', 'суффикс', [(1, 'ну'), (2, 'ть')])]
# 301 текст подтекст [('add', '', [('приставка', ['под'])])]
# текст -> подтекст : приставочный
# 302 мрак сумрак [('add', '', [('приставка', ['су'])])]
# мрак -> сумрак : приставочный
# 303 звук призвук [('add', '', [('приставка', ['при'])])]
# звук -> призвук : приставочный
# 304 дедушка прадедушка [('add', '', [('приставка', ['пра'])])]
# дедушка -> прадедушка : приставочный
# 305 друг недруг [('add', '', [('приставка', ['не'])])]
# друг -> недруг : приставочный
# 306 правда неправда [('add', '', [('приставка', ['не'])])]
# правда -> неправда : приставочный
# 307 звук ультразвук [('change', ['корень', 0], ('звук', 'ультра')), ('add', 'корень', [(1, 'звук')])]
# звук -> ультразвук : безсуффиксный
# 308 агент контрагент [('change', ['корень', 0], ('агент', 'контрагент'))]
# агент -> контрагент : безсуффиксный
# 309 компенсация декомпенсация [('add', '', [('приставка', ['де'])])]
# компенсация -> декомпенсация : приставочный
# 310 видеть предвидеть [('add', '', [('приставка', ['пред'])])]
# видеть -> предвидеть : приставочный
# 311 куда кое-куда [('change', ['корень', 0], ('куда', 'кое')), ('add', 'корень', [(1, 'куда')])]
# куда -> кое-куда : безсуффиксный
# 312 когда когда-нибудь [('add', '', [('суффикс', ['нибудь'])])]
# когда -> когда-нибудь : суффиксальный
# 313 когда когда-либо [('add', '', [('суффикс', ['либо'])])]
# когда -> когда-либо : суффиксальный
# 314 учить учиться []
# 315 какой какой-то [('add', '', [('суффикс', ['то'])])]
# какой -> какой-то : суффиксальный
# 316 колено наколенник [('add', '', [('приставка', ['на']), ('суффикс', ['ник'])])]
# колено -> наколенник : приставочно-суффиксальный
# 317 одеяло пододеяльник [('change', ['корень', 0], ('одеял', 'одеяль')), ('add', '', [('приставка', ['под']), ('суффикс', ['ник'])])]
# одеяло -> пододеяльник : приставочно-суффиксальный
# 318 дорога бездорожье [('change', ['корень', 0], ('дорог', 'дорожь')), ('add', '', [('приставка', ['без'])])]
# дорога -> бездорожье : приставочный
# 319 плечо предплечье [('change', ['корень', 0], ('плеч', 'плечь')), ('add', '', [('приставка', ['пред'])])]
# плечо -> предплечье : приставочный
# 320 звук беззвучный [('change', ['корень', 0], ('звук', 'звуч')), ('add', '', [('приставка', ['без']), ('суффикс', ['н'])])]
# звук -> беззвучный : приставочно-суффиксальный
# 321 палец напальчник cant parse напальчник, error:
# 322 береза подберезовик cant parse береза, error:
# 323 облако заоблачный [('change', ['корень', 0], ('облак', 'облач')), ('add', '', [('приставка', ['за']), ('суффикс', ['н'])])]
# облако -> заоблачный : приставочно-суффиксальный
# 324 кровать прикроватный [('change', ['корень', 0], ('кровать', 'кроват')), ('add', '', [('приставка', ['при']), ('суффикс', ['н'])])]
# кровать -> прикроватный : приставочно-суффиксальный
# 325 школа пришкольный [('change', ['корень', 0], ('школ', 'школь')), ('add', '', [('приставка', ['при']), ('суффикс', ['н'])])]
# школа -> пришкольный : приставочно-суффиксальный
# 326 рука наручники [('change', ['корень', 0], ('рук', 'руч')), ('add', '', [('приставка', ['на']), ('суффикс', ['ник'])])]
# рука -> наручники : приставочно-суффиксальный
# 327 перый во-первых cant parse перый, error:
# 328 дар бездарный [('add', '', [('приставка', ['без']), ('суффикс', ['н'])])]
# дар -> бездарный : приставочно-суффиксальный
# 329 пять впятером [('change', ['корень', 0], ('пять', 'пят')), ('add', '', [('приставка', ['в']), ('интерфикс', ['ер']), ('суффикс', ['ом'])])]
# пять -> впятером : приставочно-суффиксальный
# 330 петь припевать [('add', '', [('приставка', ['при']), ('суффикс', ['ва'])])]
# петь -> припевать : приставочно-суффиксальный
# 331 верх наверху [('add', '', [('приставка', ['на']), ('суффикс', ['у'])])]
# верх -> наверху : приставочно-суффиксальный
# 332 окно заоконный cant parse заоконный, error:
# 333 нога безногий [('add', '', [('приставка', ['без'])])]
# нога -> безногий : приставочный
# 334 лоб налобный [('add', '', [('приставка', ['на']), ('суффикс', ['н'])])]
# лоб -> налобный : приставочно-суффиксальный
# 335 езда наездник [('add', '', [('приставка', ['на']), ('суффикс', ['ник'])])]
# езда -> наездник : приставочно-суффиксальный
# 336 город загородный [('add', '', [('приставка', ['за']), ('суффикс', ['н'])])]
# город -> загородный : приставочно-суффиксальный
# 337 бежать разбежаться [('add', '', [('приставка', ['раз'])])]
# бежать -> разбежаться : приставочный
# 338 новый по-новому [('add', '', [('приставка', ['по']), ('суффикс', ['ому'])])]
# новый -> по-новому : приставочно-суффиксальный
# 339 свой по-своему [('change', ['корень', 0], ('свой', 'сво')), ('add', '', [('приставка', ['по']), ('суффикс', ['ему'])])]
# свой -> по-своему : приставочно-суффиксальный
# 340 оружие обезоружить [('change', ['корень', 0], ('оружи', 'оруж')), ('add', '', [('приставка', ['о', 'без']), ('суффикс', ['и'])])]
# оружие -> обезоружить : приставочно-суффиксальный
# 341 шеф подшефный [('add', '', [('приставка', ['под']), ('суффикс', ['н'])])]
# шеф -> подшефный : приставочно-суффиксальный
# 342 стакан подстаканник [('add', '', [('приставка', ['под']), ('суффикс', ['ник'])])]
# стакан -> подстаканник : приставочно-суффиксальный
# 343 окно подоконник [('change', ['корень', 0], ('окн', 'окон')), ('add', '', [('приставка', ['под']), ('суффикс', ['ник'])])]
# окно -> подоконник : приставочно-суффиксальный
# 344 беличий по-беличьи cant parse по-беличьи, error:
# 345 хороший по-хорошему [('add', '', [('приставка', ['по']), ('суффикс', ['ему'])])]
# хороший -> по-хорошему : приставочно-суффиксальный
# 346 далекий вдалеке cant parse далекий, error:
# 347 низ внизу [('add', '', [('приставка', ['в']), ('суффикс', ['у'])])]
# низ -> внизу : приставочно-суффиксальный
# 348 товарищеский по-товарищески [('add', 'суффикс', [(1, 'и')]), ('add', '', [('приставка', ['по'])])]
# товарищеский -> по-товарищески : приставочно-суффиксальный
# 349 водный наводнить [('add', 'суффикс', [(1, 'и')]), ('add', '', [('приставка', ['на'])])]
# водный -> наводнить : приставочно-суффиксальный
# 350 земля заземлить [('add', '', [('приставка', ['за']), ('суффикс', ['и'])])]
# земля -> заземлить : приставочно-суффиксальный
# 351 милый умилить [('add', '', [('приставка', ['у']), ('суффикс', ['и'])])]
# милый -> умилить : приставочно-суффиксальный
# 352 листва безлиственный [('add', 'суффикс', [(1, 'енн')]), ('add', '', [('приставка', ['без'])])]
# листва -> безлиственный : приставочно-суффиксальный
# 353 добрый по-доброму cant parse по-доброму, error:
# 354 луна безлуние [('add', '', [('приставка', ['без']), ('суффикс', ['и'])])]
# луна -> безлуние : приставочно-суффиксальный
# 355 снег подснежник [('change', ['корень', 0], ('снег', 'снеж')), ('add', '', [('приставка', ['под']), ('суффикс', ['ник'])])]
# снег -> подснежник : приставочно-суффиксальный
# 356 взрослый по-взрослому cant parse по-взрослому, error:
# 357 люди безлюдье [('change', ['корень', 0], ('люд', 'людь')), ('add', '', [('приставка', ['без'])])]
# люди -> безлюдье : приставочный
# 358 делать разделаться [('add', '', [('приставка', ['раз'])])]
# делать -> разделаться : приставочный
# 359 дружеский по-дружески [('add', 'суффикс', [(1, 'и')]), ('add', '', [('приставка', ['по'])])]
# дружеский -> по-дружески : приставочно-суффиксальный
# 360 зимний по-зимнему [('add', 'суффикс', [(1, 'ему')]), ('add', '', [('приставка', ['по'])])]
# зимний -> по-зимнему : приставочно-суффиксальный
# 361 дар подарок [('add', '', [('приставка', ['по']), ('суффикс', ['ок'])])]
# дар -> подарок : приставочно-суффиксальный
# 362 берег побережье [('change', ['корень', 0], ('берег', 'бережь')), ('add', '', [('приставка', ['по'])])]
# берег -> побережье : приставочный
# 363 рог безрогий [('add', '', [('приставка', ['без'])])]
# рог -> безрогий : приставочный
# 364 вред безвредный [('add', '', [('приставка', ['без']), ('суффикс', ['н'])])]
# вред -> безвредный : приставочно-суффиксальный
# 365 борода подбородок [('change', ['корень', 0], ('бород', 'подбородок'))]
# борода -> подбородок : безсуффиксный
# 366 глубокий заглубить [('change', ['корень', 0], ('глубок', 'глуб')), ('add', '', [('приставка', ['за']), ('суффикс', ['и'])])]
# глубокий -> заглубить : приставочно-суффиксальный
# 367 билет безбилетный [('add', '', [('приставка', ['без']), ('суффикс', ['н'])])]
# билет -> безбилетный : приставочно-суффиксальный
# 368 пятый в-пятых [('add', '', [('приставка', ['в']), ('суффикс', ['ых'])])]
# пятый -> в-пятых : приставочно-суффиксальный
# 369 второй во-вторых [('add', '', [('приставка', ['во']), ('суффикс', ['ых'])])]
# второй -> во-вторых : приставочно-суффиксальный
# 370 век навеки [('add', '', [('приставка', ['на']), ('суффикс', ['и'])])]
# век -> навеки : приставочно-суффиксальный
# 371 волчий по-волчьи [('change', ['корень', 0], ('волч', 'волчь')), ('change', ['суффикс', 0], ('ий', 'и')), ('add', '', [('приставка', ['по'])])]
# волчий -> по-волчьи : приставочно-суффиксальный
# 372 бровь надбровный [('change', ['корень', 0], ('бровь', 'бров')), ('add', '', [('приставка', ['над']), ('суффикс', ['н'])])]
# бровь -> надбровный : приставочно-суффиксальный
# 373 встреча навстречу [('add', '', [('приставка', ['на']), ('суффикс', ['у'])])]
# встреча -> навстречу : приставочно-суффиксальный
# 374 береза березняк cant parse береза, error:
# 375 книга книжка [('change', ['корень', 0], ('книг', 'книж')), ('add', '', [('суффикс', ['к'])])]
# книга -> книжка : суффиксальный
# 376 книга книжный [('change', ['корень', 0], ('книг', 'книж')), ('add', '', [('суффикс', ['н'])])]
# книга -> книжный : суффиксальный
# 377 книга книжник [('change', ['корень', 0], ('книг', 'книж')), ('add', '', [('суффикс', ['ник'])])]
# книга -> книжник : суффиксальный
# 378 красивый красивее [('add', 'суффикс', [(1, 'ее')])]
# красивый -> красивее : суффиксальный
# 379 бежать бежал cant parse бежал, error:
# 380 время времена cant parse времена, error:
# 381 время временной [('add', '', [('суффикс', ['ен', 'н'])])]
# время -> временной : суффиксальный
# 382 глаз глазастый [('add', '', [('суффикс', ['аст'])])]
# глаз -> глазастый : суффиксальный
# 383 синий синеть [('add', '', [('суффикс', ['е'])])]
# синий -> синеть : суффиксальный
# 384 переписать переписывать [('change', ['суффикс', 0], ('а', 'ыва'))]
# переписать -> переписывать : суффиксальный
# 385 серый серо cant parse серо, error:
# 386 серый сереть [('add', '', [('суффикс', ['е'])])]
# серый -> сереть : суффиксальный
# 387 помощь помощник [('change', ['корень', 0], ('мощь', 'мощ')), ('add', '', [('суффикс', ['ник'])])]
# помощь -> помощник : суффиксальный
# 388 камень каменщик [('change', ['корень', 0], ('камень', 'камен')), ('add', '', [('суффикс', ['щик'])])]
# камень -> каменщик : суффиксальный
# 389 парашют парашютист [('add', '', [('суффикс', ['ист'])])]
# парашют -> парашютист : суффиксальный
# 390 учить учитель [('add', 'суффикс', [(1, 'тель')])]
# учить -> учитель : суффиксальный
# 391 храбрый храбрость [('add', '', [('суффикс', ['ость'])])]
# храбрый -> храбрость : суффиксальный
# 392 строить строение cant parse строить, error:
# 393 стол столик [('add', '', [('суффикс', ['ик'])])]
# стол -> столик : суффиксальный
# 394 забота заботливый [('add', '', [('суффикс', ['лив'])])]
# забота -> заботливый : суффиксальный
# 395 весна весенний [('change', ['корень', 0], ('весн', 'весен')), ('add', '', [('суффикс', ['н'])])]
# весна -> весенний : суффиксальный
# 396 серый сероватый [('add', '', [('суффикс', ['оват'])])]
# серый -> сероватый : суффиксальный
# 397 гусь гусиный [('change', ['корень', 0], ('гусь', 'гус')), ('add', '', [('суффикс', ['ин'])])]
# гусь -> гусиный : суффиксальный
# 398 медленный медленно [('add', 'суффикс', [(1, 'о')])]
# медленный -> медленно : суффиксальный
# 399 бесшумный бесшумно cant parse бесшумно, error:
# 400 весёлый весело cant parse весело, error:
# 401 красный красноватый [('add', '', [('суффикс', ['оват'])])]
# красный -> красноватый : суффиксальный
# 402 лес лесок [('add', '', [('суффикс', ['ок'])])]
# лес -> лесок : суффиксальный
# 403 удалой удальство [('change', ['корень', 0], ('удал', 'удаль')), ('add', '', [('суффикс', ['ств'])])]
# удалой -> удальство : суффиксальный
# 404 надрезать надрезка cant parse надрезка, error:
# 405 восходить восхождение [('change', ['корень', 0], ('ход', 'хожд')), ('change', ['суффикс', 0], ('и', 'ени'))]
# восходить -> восхождение : суффиксальный
# 406 серый серость [('add', '', [('суффикс', ['ость'])])]
# серый -> серость : суффиксальный
# 407 серый серенький [('add', '', [('суффикс', ['еньк'])])]
# серый -> серенький : суффиксальный
# 408 ау аукать cant parse ау, error:
# 409 цвет цветник [('add', '', [('суффикс', ['ник'])])]
# цвет -> цветник : суффиксальный
# 410 тигр тигрица [('add', '', [('суффикс', ['иц'])])]
# тигр -> тигрица : суффиксальный
# 411 гнить гнилой [('add', 'суффикс', [(1, 'л')])]
# гнить -> гнилой : суффиксальный
# 412 спеть спелый cant parse спеть, error:
# 413 зреть зрелый cant parse зреть, error:
# 414 богатый богатеть [('add', '', [('суффикс', ['е'])])]
# богатый -> богатеть : суффиксальный
# 415 старый стареть [('add', '', [('суффикс', ['е'])])]
# старый -> стареть : суффиксальный
# 416 ржавый ржаветь [('add', 'суффикс', [(1, 'е')])]
# ржавый -> ржаветь : суффиксальный
# 417 белый белеть [('add', '', [('суффикс', ['е'])])]
# белый -> белеть : суффиксальный
# 418 белый белить [('add', '', [('суффикс', ['и'])])]
# белый -> белить : суффиксальный
# 419 танец танцевать [('change', ['корень', 0], ('танец', 'танц')), ('add', '', [('суффикс', ['ева'])])]
# танец -> танцевать : суффиксальный
# 420 решить решать [('change', ['суффикс', 0], ('и', 'а'))]
# решить -> решать : суффиксальный
# 421 пленить пленять [('change', ['суффикс', 0], ('и', 'я'))]
# пленить -> пленять : суффиксальный
# 422 бросить бросать [('change', ['суффикс', 0], ('и', 'а'))]
# бросить -> бросать : суффиксальный
# 423 рассказать рассказывать [('change', ['суффикс', 0], ('а', 'ыва'))]
# рассказать -> рассказывать : суффиксальный
# 424 утаить утаивать [('change', ['суффикс', 0], ('и', 'ива'))]
# утаить -> утаивать : суффиксальный
# 425 настоять настаивать [('change', ['корень', 0], ('сто', 'наста')), ('change', ['суффикс', 0], ('я', 'ива')), ('remove', 'суффикс', [(1, 'ть')]), ('remove', '', [('приставка', ['на'])])]
# настоять -> настаивать : безсуффиксный
# 426 о окать cant parse о, error:
# 427 ох охать cant parse ох, error:
# 428 хи-хи хихикать cant parse хи-хи, error:
# 429 мяу мяукать [('add', '', [('суффикс', ['ка'])])]
# мяу -> мяукать : суффиксальный
# 430 близкий близко cant parse близко, error:
# 431 певучий певуче cant parse певуче, error:
# 432 дружеский дружески cant parse дружески, error:
# 433 человеческий человечески cant parse человечески, error:
# 434 один однажды [('change', ['корень', 0], ('один', 'одн')), ('add', '', [('суффикс', ['а', 'жды'])])]
# один -> однажды : суффиксальный
# 435 два дважды [('add', '', [('суффикс', ['а', 'жды'])])]
# два -> дважды : суффиксальный
# 436 три трижды [('add', '', [('суффикс', ['и', 'жды'])])]
# три -> трижды : суффиксальный
# 437 четыре четырежды [('add', '', [('суффикс', ['е', 'жды'])])]
# четыре -> четырежды : суффиксальный
# 438 одарить одарённый [('change', ['суффикс', 0], ('и', 'енн'))]
# одарить -> одарённый : суффиксальный
# 439 квасить квашеный [('change', ['корень', 0], ('квас', 'кваш')), ('change', ['суффикс', 0], ('и', 'ен'))]
# квасить -> квашеный : суффиксальный
# 440 жарить жареный [('change', ['суффикс', 0], ('и', 'ен'))]
# жарить -> жареный : суффиксальный
# 441 плюш плюшевый [('add', '', [('суффикс', ['ев'])])]
# плюш -> плюшевый : суффиксальный
# 442 учитель учительница [('add', 'суффикс', [(2, 'ниц')])]
# учитель -> учительница : суффиксальный
# 443 лыжа лыжник [('add', '', [('суффикс', ['ник'])])]
# лыжа -> лыжник : суффиксальный
# 444 нормировать нормировщик [('change', ['суффикс', 0], ('ир', 'ов')), ('change', ['суффикс', 1], ('ова', 'щик')), ('add', '', [('интерфикс', ['ир'])])]
# нормировать -> нормировщик : суффиксальный
# 445 кормить кормилец [('add', 'суффикс', [(1, 'ец')]), ('add', '', [('интерфикс', ['л'])])]
# кормить -> кормилец : суффиксальный
# 446 соус соусник [('add', '', [('суффикс', ['ник'])])]
# соус -> соусник : суффиксальный
# 447 черника черничник [('change', ['суффикс', 0], ('ик', 'ич')), ('add', 'суффикс', [(1, 'ник')])]
# черника -> черничник : суффиксальный
# 448 добрый доброта [('add', '', [('суффикс', ['от'])])]
# добрый -> доброта : суффиксальный
# 449 нищий нищета [('add', '', [('суффикс', ['ет'])])]
# нищий -> нищета : суффиксальный
# 450 жёлтый желтизна [('add', '', [('суффикс', ['изн'])])]
# жёлтый -> желтизна : суффиксальный
# 451 седой седина [('add', '', [('суффикс', ['ин'])])]
# седой -> седина : суффиксальный
# 452 смелый смелость [('add', 'суффикс', [(1, 'ость')])]
# смелый -> смелость : суффиксальный
# 453 свежий свежесть [('add', '', [('суффикс', ['есть'])])]
# свежий -> свежесть : суффиксальный
# 454 похожий похожесть cant parse похожесть, error:
# 455 студент студентка [('add', '', [('суффикс', ['к'])])]
# студент -> студентка : суффиксальный
# 456 попытаться попытка [('change', ['суффикс', 0], ('а', 'к'))]
# попытаться -> попытка : суффиксальный
# 457 задвигать задвижка [('change', ['корень', 0], ('двиг', 'движ')), ('change', ['суффикс', 0], ('а', 'к'))]
# задвигать -> задвижка : суффиксальный
# 458 покрасить покраска [('change', ['суффикс', 0], ('и', 'к'))]
# покрасить -> покраска : суффиксальный
# 459 рубцеваться рубцевание [('add', 'суффикс', [(2, 'ни')])]
# рубцеваться -> рубцевание : суффиксальный
# 460 полоскать полоскание [('add', 'суффикс', [(1, 'ни')])]
# полоскать -> полоскание : суффиксальный
# 461 река речной [('change', ['корень', 0], ('рек', 'реч')), ('add', '', [('суффикс', ['н'])])]
# река -> речной : суффиксальный
# 462 окно оконный [('change', ['корень', 0], ('окн', 'окон')), ('add', '', [('суффикс', ['н'])])]
# окно -> оконный : суффиксальный
# 463 салат салатный [('add', '', [('суффикс', ['н'])])]
# салат -> салатный : суффиксальный
# 464 береста берестяной [('add', '', [('суффикс', ['ян'])])]
# береста -> берестяной : суффиксальный
# 465 рожь ржаной [('change', ['корень', 0], ('рожь', 'рж')), ('add', '', [('суффикс', ['ан'])])]
# рожь -> ржаной : суффиксальный
# 466 солома соломенный [('add', '', [('суффикс', ['енн'])])]
# солома -> соломенный : суффиксальный
# 467 село сельский [('change', ['корень', 0], ('сел', 'сель')), ('add', '', [('суффикс', ['ск'])])]
# село -> сельский : суффиксальный
# 468 нос носатый [('add', '', [('суффикс', ['ат'])])]
# нос -> носатый : суффиксальный
# 469 игра игривый [('add', '', [('суффикс', ['ив'])])]
# игра -> игривый : суффиксальный
# 470 прополоть прополка [('change', ['суффикс', 0], ('о', 'к'))]
# прополоть -> прополка : суффиксальный
# 471 тоска тосковать [('add', '', [('суффикс', ['ова'])])]
# тоска -> тосковать : суффиксальный

# %%
len(res), test.shape
# Out:
# (472, (472, 4))

# %%
test['res'] = res

# %%
p.get_POS('уплатить'), p.get_POS('уплата')
# Out:
# ('INFN', 'NOUN')

# %%
test.head(10)
# Out:
#    Unnamed: 0         word1     word2 label                  res
# 0           0     надрезать    надрез     B                    B
# 1           1        водить     вождь     B                    B
# 2           2    лед колоть   ледокол     B  UNKNOWN_PARSE_ERROR
# 3           3  сталь варить  сталевар     B  UNKNOWN_PARSE_ERROR
# 4           4     подорвать    подрыв     B                    B
# 5           5      отводить     отвод     B                    B
# 6           6        дарить       дар     B                    B
# 7           7      взрывать     взрыв     B                    B
# 8           8       гладкий     гладь     B                    B
# 9           9      глубокий     глубь     B                    B

# %%
test.label.value_counts()
# Out:
# B     230
# S      98
# P      82
# PS     58
# PF      4
# Name: label, dtype: int64

# %%
print('accuracy measuring')

total_acc = sum(test.label==test.res) / test.shape[0]
print('total accuracy: ', total_acc)

for l in test.label.unique():
    filt = test.label==l
    tmp_acc = sum(test[filt].label==test[filt].res) / (test[filt].shape[0] +0.1)
    print(l, ' accuracy: ', tmp_acc)
# Out:
# accuracy measuring
# total accuracy:  0.792372881356
# B  accuracy:  0.83876575402
# P  accuracy:  0.755176613886
# PF  accuracy:  0.0
# PS  accuracy:  0.705679862306
# S  accuracy:  0.795107033639

# %%
test[test.res=='UNKNOWN_PARSE_ERROR'].shape
# Out:
# (52, 5)

# %%
p.analyze('река', 'речной')
# Out:
# [('change', ['корень', 0], ('рек', 'реч')), ('add', '', [('суффикс', ['н'])])]
# река -> речной : безсуффиксный
# 'B'

# %%
sp1.get_morphems('страдать'), sp3.get_morphems('страдать'), sp1.get_morphems('сострадать'), sp3.get_morphems('сострадать'),
# Out:
# ([('страда', 'корень'), ('ть', 'глагольноеокончание')],
#  [('страда', 'корень'), ('ть', 'суффикс')],
#  [('со', 'приставка'),
#   ('страд', 'корень'),
#   ('а', 'суффикс'),
#   ('ть', 'глагольноеокончание')],
#  [('со', 'приставка'), ('страда', 'корень'), ('ть', 'постфикс')])

# %%
p.get_POS('сколько'), p.get_POS('несколько'),
# Out:
# ('CONJ', 'ADVB')

# %%
лис	лиса	
кум	кума
золото	золотой

# %%
['кое-', 'ультра', 'контр']

# %%
test[(test.label!=test.res) & (test.res!='UNKNOWN_PARSE_ERROR')]
# Out:
#      Unnamed: 0           word1             word2 label        res
# 13           13             кум              кума     B    UNKNOWN
# 14           14             лис              лиса     B    UNKNOWN
# 17           17          золото           золотой     B    UNKNOWN
# 21           21            ниже            низший     B          S
# 33           33        вызывать             вызов     B  DIFF_ROOT
# 47           47          подвод         подводить     B          S
# 48           48         разъезд        разъезжать     B          S
# 56           56        высевать             высев     B          S
# 121         121          прясть             пряжа     B          S
# 123         123  пересматривать         пересмотр     B  DIFF_ROOT
# 173         173       слетаться              слёт     B  DIFF_ROOT
# 188         188        забивать             забой     B  DIFF_ROOT
# 196         196        завозить             завоз     B  DIFF_ROOT
# 205         205      извиваться             извив     B          S
# 207         207        наливать             налив     B          S
# 211         211       наплывать            наплыв     B          S
# 213         213       нагревать            нагрев     B          S
# 215         215       нарастать            нарост     B  DIFF_ROOT
# 229         229         нанести             нанос     B  DIFF_ROOT
# 230         230             кто           кое-кто     P  DIFF_ROOT
# 238         238        страдать        сострадать     P         PS
# 241         241            лево            налево     P         PS
# 245         245          решать         разрешать     P          B
# 254         254     мобилизация     демобилизация     P         PS
# 270         270    общественный  антиобщественный     P         PS
# 274         274             что           кое-что     P  DIFF_ROOT
# 278         278            петь            запеть     P         PS
# 279         279            ныне            поныне     P         PS
# 300         300        кликнуть       воскликнуть     P  DIFF_ROOT
# 307         307            звук        ультразвук     P          B
# 308         308           агент        контрагент     P          B
# 311         311            куда          кое-куда     P          B
# 312         312           когда      когда-нибудь    PF          S
# 313         313           когда        когда-либо    PF          S
# 314         314           учить           учиться    PF    UNKNOWN
# 315         315           какой          какой-то    PF          S
# 318         318          дорога        бездорожье    PS          P
# 319         319           плечо        предплечье    PS          P
# 333         333            нога          безногий    PS          P
# 337         337          бежать       разбежаться    PS          P
# 357         357            люди          безлюдье    PS          P
# 358         358          делать       разделаться    PS          P
# 362         362           берег         побережье    PS          P
# 363         363             рог          безрогий    PS          P
# 365         365          борода        подбородок    PS          B
# 425         425        настоять        настаивать     S          B

# %%
p.analyze('бежать', 'бежал')
# Out:
# [('remove', '', [('корень', ['беж']), ('суффикс', ['а'])])]
# 'UNKNOWN'

# %%
sp1.get_morphems('бежать'), sp1.get_morphems('бежал'),
# Out:
# ([('беж', 'корень'), ('а', 'суффикс'), ('ть', 'глагольноеокончание')],
#  {'error': 'site parsing error'})

# %%
sp3.get_morphems('бежать'), sp3.get_morphems('бежал'),
# Out:
# ([('беж', 'корень'), ('а', 'суффикс'), ('ть', 'суффикс')], [])

# %%
p._find([('change', ['корень', 0], ('беж', 'бег')), ('remove', '', [('суффикс', ['а'])])], 'add', 'суффикс')
# Out:
# False

# %%
dif = [('add', '', [('приставка', ['в']), ('суффикс', ['ых'])])]

# %%
s = p._find(dif, action='add', morpheme='суффикс')

# %%
s
# Out:
# True
